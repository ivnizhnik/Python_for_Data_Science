# %% [markdown]
# <a href="https://colab.research.google.com/github/ivnizhnik/Python_for_Data_Science/blob/main/Analysis_on_Mortgage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df='/content/mortgages.csv'
df=pd.read_csv(df)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Month  Starting Balance  Repayment  ...  New Balance  Mortgage Name  Interest Rate
# 0      1         400000.00    1686.42  ...    399313.58        30 Year           0.03
# 1      2         399313.58    1686.42  ...    398625.44        30 Year           0.03
# 2      3         398625.44    1686.42  ...    397935.58        30 Year           0.03
# 3      4         397935.58    1686.42  ...    397243.99        30 Year           0.03
# 4      5         397243.99    1686.42  ...    396550.67        30 Year           0.03
#
# [5 rows x 8 columns]

# %%
df['Mortgage Name'].value_counts()
# Out:
# 30 Year    720
# 15 Year    360
# Name: Mortgage Name, dtype: int64

# %%
df['Interest Rate'].value_counts()
# Out:
# 0.05    540
# 0.03    540
# Name: Interest Rate, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             1080 non-null   int64
#  1   Starting Balance  1080 non-null   float64
#  2   Repayment         1080 non-null   float64
#  3   Interest Paid     1080 non-null   float64
#  4   Principal Paid    1080 non-null   float64
#  5   New Balance       1080 non-null   float64
#  6   Mortgage Name     1080 non-null   object
#  7   Interest Rate     1080 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 67.6+ KB

# %%
mortgage30y_Filter = df['Mortgage Name'] == '30 Year'
df.loc[mortgage30y_Filter, :]
# Out:
#      Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 0        1         400000.00  ...        30 Year           0.03
# 1        2         399313.58  ...        30 Year           0.03
# 2        3         398625.44  ...        30 Year           0.03
# 3        4         397935.58  ...        30 Year           0.03
# 4        5         397243.99  ...        30 Year           0.03
# ..     ...               ...  ...            ...            ...
# 715    356          10596.54  ...        30 Year           0.05
# 716    357           8493.40  ...        30 Year           0.05
# 717    358           6381.49  ...        30 Year           0.05
# 718    359           4260.78  ...        30 Year           0.05
# 719    360           2131.24  ...        30 Year           0.05
#
# [720 rows x 8 columns]

# %%
interest3_Filter = df['Interest Rate']==0.03
df.loc[interest3_Filter, :]
# Out:
#      Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 0        1         400000.00  ...        30 Year           0.03
# 1        2         399313.58  ...        30 Year           0.03
# 2        3         398625.44  ...        30 Year           0.03
# 3        4         397935.58  ...        30 Year           0.03
# 4        5         397243.99  ...        30 Year           0.03
# ..     ...               ...  ...            ...            ...
# 895    176          13706.74  ...        15 Year           0.03
# 896    177          10978.67  ...        15 Year           0.03
# 897    178           8243.78  ...        15 Year           0.03
# 898    179           5502.05  ...        15 Year           0.03
# 899    180           2753.47  ...        15 Year           0.03
#
# [540 rows x 8 columns]

# %%
interest5_Filter = df['Interest Rate']==0.05
df.loc[interest5_Filter, :]
# Out:
#       Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 360       1         400000.00  ...        30 Year           0.05
# 361       2         399519.37  ...        30 Year           0.05
# 362       3         399036.74  ...        30 Year           0.05
# 363       4         398552.10  ...        30 Year           0.05
# 364       5         398065.44  ...        30 Year           0.05
# ...     ...               ...  ...            ...            ...
# 1075    176          15619.91  ...        15 Year           0.05
# 1076    177          12521.82  ...        15 Year           0.05
# 1077    178           9410.82  ...        15 Year           0.05
# 1078    179           6286.86  ...        15 Year           0.05
# 1079    180           3149.88  ...        15 Year           0.05
#
# [540 rows x 8 columns]

# %%
filter_30y5 = mortgage30y_Filter & interest5_Filter
df.loc[filter_30y5, :]
# Out:
#      Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 360      1         400000.00  ...        30 Year           0.05
# 361      2         399519.37  ...        30 Year           0.05
# 362      3         399036.74  ...        30 Year           0.05
# 363      4         398552.10  ...        30 Year           0.05
# 364      5         398065.44  ...        30 Year           0.05
# ..     ...               ...  ...            ...            ...
# 715    356          10596.54  ...        30 Year           0.05
# 716    357           8493.40  ...        30 Year           0.05
# 717    358           6381.49  ...        30 Year           0.05
# 718    359           4260.78  ...        30 Year           0.05
# 719    360           2131.24  ...        30 Year           0.05
#
# [360 rows x 8 columns]

# %%
OR

# %%
filter_30y5 = df.loc[mortgage30y_Filter & interest5_Filter, :]
filter_30y5.head()
# Out:
#      Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 360      1         400000.00  ...        30 Year           0.05
# 361      2         399519.37  ...        30 Year           0.05
# 362      3         399036.74  ...        30 Year           0.05
# 363      4         398552.10  ...        30 Year           0.05
# 364      5         398065.44  ...        30 Year           0.05
#
# [5 rows x 8 columns]

# %%
filter_30y3 = mortgage30y_Filter & interest3_Filter
df.loc[filter_30y3, :]
# Out:
#      Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 0        1         400000.00  ...        30 Year           0.03
# 1        2         399313.58  ...        30 Year           0.03
# 2        3         398625.44  ...        30 Year           0.03
# 3        4         397935.58  ...        30 Year           0.03
# 4        5         397243.99  ...        30 Year           0.03
# ..     ...               ...  ...            ...            ...
# 355    356           8364.12  ...        30 Year           0.03
# 356    357           6698.61  ...        30 Year           0.03
# 357    358           5028.93  ...        30 Year           0.03
# 358    359           3355.08  ...        30 Year           0.03
# 359    360           1677.04  ...        30 Year           0.03
#
# [360 rows x 8 columns]

# %%
filter_30y5 = df.loc[mortgage30y_Filter & interest5_Filter, :]
filter_30y5['Interest Paid'].cumsum()
# Out:
# 360      1666.66
# 361      3331.32
# 362      4993.97
# 363      6654.60
# 364      8313.20
#          ...
# 715    372928.64
# 716    372964.02
# 717    372990.60
# 718    373008.35
# 719    373017.23
# Name: Interest Paid, Length: 360, dtype: float64

# %%
filter_30y3 = df.loc[mortgage30y_Filter & interest3_Filter, :]
filter_30y3['Interest Paid'].cumsum()
# Out:
# 0        1000.00
# 1        1998.28
# 2        2994.84
# 3        3989.67
# 4        4982.77
#          ...
# 355    207064.13
# 356    207080.87
# 357    207093.44
# 358    207101.82
# 359    207106.01
# Name: Interest Paid, Length: 360, dtype: float64

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (12, 7))
axes.plot(filter_30y3['Month'], filter_30y3['Interest Paid'].cumsum(), color = 'blue', label = '30 year mortgage at 3%');
axes.plot(filter_30y5['Month'], filter_30y5['Interest Paid'].cumsum(), color = 'black', label = '30 year mortgage at 5%');
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Dollars', fontsize = 15)
plt.title('Cumulative Interest Paid', fontsize = 25, c='g')
plt.grid()
plt.xticks(fontsize = 15) 
plt.yticks(fontsize = 15);
plt.legend();
